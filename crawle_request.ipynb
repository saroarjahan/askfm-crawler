# %%
# !pip install requests-html
# !pip install selenium-requests

# %%
#collect users and save to csv file, uncomment this code if new user needed to generate
# for x in range(300):
#     user=crawler.crawl_random_users()
#     m=20
#     for i in range(m):
#         with open('users.csv','a') as file:
#             file.write((user[i].encode('ascii','ignore')).decode('utf-8'))
#             file.write('\n')

# %%
#remove duplicate users name 
from more_itertools import unique_everseen
with open('users.csv','r') as f, open('users_usa.csv','w') as out_file:
    out_file.writelines(unique_everseen(f))

# %%
import pandas as pd
file_name = "users_usa.csv"
user = pd.read_csv(file_name)
print(user["name"][1])
len(user)
# Out:
# PithipolKuakoon
# 3271

# %%
#load swearwords
swear = open("negativewords.txt", "r", encoding="utf8")
swear=swear.read().split(',')
swear=list(dict.fromkeys(swear)) #remove duplicate swear words
print(len(swear))
print(swear[0])
# Out:
# 306
# ﻿arse

# %%
#test run for a single threds url, just for test 
import numpy as np
import pandas as pd
from requests_html import HTMLSession
session = HTMLSession()

r = session.get('https://ask.fm'+'/Isabel_2002_/threads/157061911830')
Q = r.html.find('.streamItem_header')
A = r.html.find('.streamItem_content')
Q_1 = r.html.find('.big')

for x in range(len(Q)):
    try:   
        if x==0:
            q_ans=Q_1[x].text+' => '+A[x].text
        else:
            q_ans=Q[x].text+' => '+A[x].text 
        print(q_ans)
        for w in range(len(swear)):
            if swear[w] in str(q_ans).split():
                print(q_ans)
#                 with open('output.csv','a') as file:
#                     file.write((q_ans.encode('ascii','ignore')).decode('utf-8'))
#                     file.write('\n')
        
    except:
        x=1
# Out:
# Hello! => Hii
# How are you? => I'm wonderful, how are you?
# I’m also wonderful for you saying wonderful😊😂 => Yayyyy

# %%
from requests_html import HTMLSession
from selenium import webdriver
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
# user=['Isabel_2002_'] #load username for askfm

for i in range(20,30):#run loop for each askfm user
    driver = webdriver.Chrome()#load crome driver, make sure chome browser version 70-73
    driver.get('https://ask.fm/'+user["name"][i])

    SCROLL_PAUSE_TIME = 1 #code for infinity page scroll
    # Get scroll height
    last_height = driver.execute_script("return document.body.scrollHeight")
    while True:
        # Scroll down to bottom
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

        # Wait to load page
        time.sleep(SCROLL_PAUSE_TIME)

        # Calculate new scroll height and compare with last scroll height
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break
        last_height = new_height


    soup = BeautifulSoup(driver.page_source,'html.parser') #get all the html content
    for item in soup.find_all('article',class_="streamItem-answer"):#find specifc content with class name
        try:
            arry_data=item.find_all('h2',class_="medium")[0].contents+item.find_all('div',class_="streamItem_content")[0].contents 
            q_ans=arry_data
            q_ans=q_ans[0]+' => '+q_ans[1]
            for w in range(len(swear)):#swear word string match
                if swear[w] in str(q_ans).split():
                    print(q_ans)
                    with open('output.csv','a') as file:
                        file.write((q_ans.encode('ascii','ignore')).decode('utf-8'))
                        file.write('\n')
        except:
            print("An exception occurred")
            arry_data=item.find_all('a',class_="streamItem_threadDetails")
            for link in arry_data:        
                content=str(link.find_all('span'))
                if 'Read more' in content:
                    linkread=str(link.get('href'))
                    session = HTMLSession()
                    r = session.get('https://ask.fm'+linkread)
                    Q = r.html.find('.streamItem_header')
                    A = r.html.find('.streamItem_content')
                    Q_1 = r.html.find('.big')
                    
                    for x in range(len(Q)):
                        try:   
                            if x==0:
                                q_ans=Q_1[x].text+' => '+A[x].text
                            else:
                                q_ans=Q[x].text+' => '+A[x].text  
                            for w in range(len(swear)):#swear word string match
                                if swear[w] in str(q_ans).split():
                                    print(q_ans)
                                    with open('output.csv','a') as file:
                                        file.write((q_ans.encode('ascii','ignore')).decode('utf-8'))
                                        file.write('\n')
                        except:
                            print("An exception occurred in second browse")
# Out:
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# If you could say something to your younger self, what would you say? => Move your ass and do stuff
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# Did you poop today or not yet => Yes
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# If you could replace anything from your body,what would it be?😅 => My legs and butt
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# What makes you nervous? => People who talk too much not knowing shit :)
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# Are you a shopaholic? => Hell yea
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# What to do, if I want to work? ? => Get your ass off the couch
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# Why are some men thin, and others fat, although they eat the same pasta? => There are many lucky pieces of shit in the world lol
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# Quale persona famosa ti piacerebbe incontrare? => Michael Phelps
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# Chi è il tuo atleta preferito? => Michael Phelps
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# Hai Mai fatto sex prima di una gara? => Dipende quanto prima intendi aha
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# Quale persona famosa ti piacerebbe incontrare? => Michael Phelps <3
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# If you had an ability to look into other's past, who would be the first one on which you will use your power? => Keep that shit dormant, it’s rude to pry
# How will u feel to talk to a person, you don't even know the name ? => I’d be okay with it as long as they don’t show signs of being a dick
# An exception occurred
# What gift would you like to receive? From who? => Well I asked someone for regular men’s T-shirts but they are so unaccepting that they got me a goddamn designer women’s bag that was far more expensive, those assholes. I’m getting tired of it, maybe they could get me at least one decent T-shirt.
# An exception occurred
# An exception occurred
# Who do you trust the most? => I don’t trust a damn soul, who do you think I am?
# An exception occurred
# An exception occurred
# Which three things would you take to a deserted island? => Me. I’d starve and die no doubts about it. Maybe a phone and a WiFi device that somehow works
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# What is at the same time funny and sad? => I can’t feel a damn thing
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# If your clothes all had a personality, which do you think would like you the least? => My long sleeve dark gray shirt, he’s the shit
# An exception occurred
# An exception occurred
# Di you are really an inspiration to me i would really like to meet you and spend some time with you i adore you a lot ?you are damn pretty ? => Well thanks and nice use of question marks lol. Also I don’t know about the whole meeting thing. I don’t go out much and my mom would bug me about it. But thanks anyways, frendo.
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# Who you going on a date with?😪 => No one, not for a while until her parents stop being little bitches
# An exception occurred
# Are you living your dream ? => Hell no
# An exception occurred
# An exception occurred
# You have an opportunity to make one person absolutely happy, but not yourself. Who => My significant other, if I used it on my mom it would go to waste because she refuses to let herself appear happy in order to guilt everyone into doing shit for her
# An exception occurred
# An exception occurred
# An exception occurred
# Where do the happiest people live? => Hell if I know
# Anyone else having a really shitty day? :( => I’m always having a shitty day
# An exception occurred
# What gives you immense pleasure? => When someone addresses me as male without me even telling them, unlike some people’s leg who aggressively misgender me even though I’ve told them time and time again. I don’tind if you don’t know, but if I’ve told you a thousand times and you PURPOSELY misgender me, I might slap a bitch some day.
# An exception occurred
# An exception occurred
# What should a woman be like? ? => Whatever the heck they wanna be, other than an asshole or feminazi. It’s okay to be a feminist, just don’t be a nazi about it
# An exception occurred
# An exception occurred
# heyyy guys im rly happy it’s summer bc school makes me wanna die => Same
# An exception occurred
# An exception occurred
# What does true friendship mean to you? => They don’t care about you having no problems, they’re just there to laugh with you and talk shit about your enemies with you :)
# What is one thing you will never do again? => Tell anyone in my family the truth about myself in any way, since they always seem to take it as if I am the devil and/or need to suck it up
# An exception occurred
# YOOOOOO
#
# Who's gay asf like me?! => Just about 😂
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# Who was your hero in childhood? Why? => My biggest hero was and is still Brendon Urie. This is simply because his vocal range is to die for and he’s extremely accepting and protective of anyone not being accepted. Honestly, he is one of the best people on this earth. And yes I know he smokes weed, but that’s exactly like drinking without the addiction or bodily harm so it doesn’t sway my opinion. (It does kind of smell though)
# An exception occurred
# What was the last thing made you feel sick? => Literally sick? Coffee. Sick of humanity or disgusted? Family talking shit about everyone not Christian, straight, or cis.
# Do you think that tickling could be used to punish teens? => Hell yeah it could, unless they aren’t ticklish
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# Why do drivers violate the traffic rules? 🚨🚔 => Because they suck 🤷🏾‍♂️
# If you jumped into a black hole, would you come out as a pancake or as a pink rabbit? => Technically, you wouldn’t come out at all. It’s quite amazing but when one falls in to a black hole, everything but what’s in that hole seems slow due to you moving unhealthily fast into the black hole. They could be about to blink as you disappear and you’d see it all. Of course, you’d die shortly after witnessing it because you’re being sucked into a black whole. That kills people, y’know 🙃
# What is the most important thing in life? => The most important thing in life for me is... well heck I don’t know. I don’t find meaning in a lot of things these days. I’d die for anyone I know but that’s probably just because I really just want to, not for heroic purposes.
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred in second browse
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# are you gay cuz you look it => Tf
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# Is that okay when a girlfriend hugging her male friends?What do you think? => Yeah? I hug my male friends all the damn time and my boyfriend has no issue with it. Same with my friend's boyfriend. It's only the jealous types that get upset when their girlfriend hugs her male friends.
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# Do you believe in karma? => Hell yes. My bully has what's coming to her.
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# Do you keep your room clean or messy? => Well it's messy right now (but that's because I've been too lazy and sore to get off my ass and clean it XD)
# An exception occurred
# Nuu don't say that Rainbow-san ): => Mubi-sannnnnnn I said that because I was feeling like shit but I'm okay now.
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# Do you treat your body like a Temple or more like an Amusement Park? => da fuck does that even mean? OAO
# An exception occurred
# An exception occurred
# An exception occurred
# crying because you're so damn sweet. q u q => q u q love youuuu~ <3333
# How are you feeling right now? => Hm kinda shitty actually. Today was a bad day.
# What was the last book you read? => Uhhhhhhhhh....... I had to read Cold Mountain for school and it was boring.... omg
# Do you like high heels? => OMG hell no.... I am a tomboy plz.... sneakers and tennis shoes... NEVER girly shoes unless it's absolutely REQUIRED as a dress code -sobs- .... even then I wear flats.... >A>
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# What do you like to see in a good leader? => I like to see a good leader actually take charge instead of forcing his/her jobs on the 2nd in commands or lower ranked people. In chorus groups on YT, a lot of the leaders never check the project auditions or reply to PMs. This is why a lot of the groups die out before their first song ever shows up. I've had a couple of groups do that to me and others! ^ ^'' So I think a good leader doesn't let their group die and if someone is holding the group back, the leader should pull them aside and help the person. Sorry if my answer is unclear. I am pretty bad at getting a point across! ^ ^''
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# What words of wisdom would you want to pass on to me? => Umm..... don't be a potato.... be the best goddamn tomato you can ever be?
# An exception occurred
# An exception occurred
# Do you like butt sex? => O_O
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# ??What would you say to your young self and why? => I wouldn’t say anything tbh cuz even though my mental health is crap I’m happy with my life currently
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# What one thing would you do to change the world? => Probably make gay the norm
# Have you resolved to lead a healthier lifestyle in the new year? => Haha I gave that shit up
# An exception occurred
# what can men get away with that women can’t? => Usually sleeping with a bunch of people and being honored as a champion while if women do it they’re called a slut
# An exception occurred
# What's your today midnight thoughts ? => We could die any day now
# An exception occurred
# An exception occurred
# An exception occurred
# Post your most favourite lyrics? => "If you're gay then you're gay,
# An exception occurred
# What has been one of the best days of your life => When I was in 5th grade and I made a freaking long ass rainbow loom bracelet/necklace
# An exception occurred
# Di you are really an inspiration to me i would really like to meet you and spend some time with you i adore you a lot ?you are damn pretty ? => It makes me so happy to know that I’m an inspiration to someone and thanks for the compliment but just saying this I’m still a minor and I have a boyfriend—besides that feel free to DM me
# An exception occurred
# What's the fastest way to make a situation awkward ? => Mention really detailed sex
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# Are you ready for the Halloween night? => Hell yeah! Kind of actually I haven’t decided what I’m going to be.
# An exception occurred
# An exception occurred
# An exception occurred
# What kind of school bus is too hot for you? => Why the fuck are you talking about school buses
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# Do you believe in Love? => Hell yeah
# An exception occurred
# An exception occurred
# Who is a dude and gay and single => Wha? Idk why I would know this and even if I did I wouldn’t tell you
# An exception occurred
# An exception occurred
# What contains ten thousand calories? ?? => Why the hell would I know this?
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
